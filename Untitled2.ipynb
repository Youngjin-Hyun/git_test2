# %%
import librosa
print(librosa.__version__)
# Out:
# 0.5.1

# %%
y, sr = librosa.load(librosa.util.example_audio_file())
print(len(y),sr)
# Out:
# 1355168 22050

# %%
y_orig, sr_orig = librosa.load(librosa.util.example_audio_file(),sr=None)
print(len(y_orig), sr_orig)
# Out:
# 2710336 44100

# %%
sr = 22050
y = librosa.resample(y_orig,sr_orig, sr)
print(len(y), sr)
# Out:
# 1355168 22050

# %%
print(librosa.samples_to_time(len(y),sr))
# Out:
# [ 61.45886621]

# %%
D = librosa.stft(y)
print(D.shape,D.dtype)
# Out:
# (1025, 2647) complex64

# %%
import numpy as np

# %%
S, phase = librosa.magphase(D)
print(S.dtype,phase.dtype,np.allclose(D,S*phase))
# Out:
# float32 complex64 True

# %%
C = librosa.cqt(y, sr=sr)

# %%
print(C.shape,C.dtype)
# Out:
# (84, 2647) complex128

# %%
import librosa.display

# %%
meclspec=librosa.feature.melspectrogram(y=y, sr=sr)

# %%
melspec = librosa.feature.melspectrogram(y=y,sr=sr)

# %% [markdown]
# y, sr = librosa.load(librosa.util.example_audio_file())
# print(len(y),sr)

# %%
melspec =librosa.feature.melspectrogram(y=y,sr=sr)

# %%
melspec_stft = librosa.feature.melspectrogram(S=S**2,sr=sr)
print(np.allclose(melspec, melspec_stft))
# Out:
# True

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.style as ms

# %%
ms.use('seaborn-muted')

# %%
from IPython.display import Audio

# %%
import IPython

# %%
plt.figure()
librosa.display.waveplot(y=y, sr=sr)

# %%
# %matplotlib nbagg

# %%
plt.figure()
librosa.display.waveplot(y=y, sr=sr)
# Out:
# <div id='13878bb3-5f97-4239-9e78-b87f527f2696'></div>

# %%
import librosa.display

# %%
plt.figure()
librosa.display.waveplot(y=y, sr=sr)
# Out:
# <div id='9777c8f2-c2ea-4fca-9a52-44b6e04aef3a'></div>

# %%
plt.figure()
librosa.display.specshow(melspec, y_axis='mel', x_axis='time')
plt.colorbar()
# Out:
# <div id='15a255d3-5600-4f8d-b918-03935aba72de'></div>

# %%
tempo,beats = librosa.beat.beat_track(y=y,sr=sr)

# %%
print(tempo)
# Out:
# 129.19921875

# %%
print(beats)
# Out:
# [   5   24   43   63   83  103  122  142  162  182  202  222  242  262  281
#   301  321  341  361  382  401  421  441  461  480  500  520  540  560  580
#   600  620  639  658  678  698  718  737  758  777  798  817  837  857  877
#   896  917  936  957  976  996 1016 1036 1055 1075 1095 1116 1135 1155 1175
#  1195 1214 1234 1254 1275 1295 1315 1334 1354 1373 1394 1414 1434 1453 1473
#  1493 1513 1532 1553 1573 1593 1612 1632 1652 1672 1691 1712 1732 1752 1771
#  1791 1811 1831 1850 1871 1890 1911 1931 1951 1971 1990 2010 2030 2050 2070
#  2090 2110 2130 2150 2170 2190 2209 2229 2249 2269 2289 2309 2328 2348 2368
#  2388 2408 2428 2448 2468 2488 2508 2527 2547]

# %%
plt.figure()
librosa.display.specshow(melspec, y_axis='mel', x_axis='time')
plt.colorbar()
# Out:
# <div id='0dd6a8cf-aaa2-4b78-bf6a-d501db7d3bd9'></div>

# %%
melspec = librosa.feature.melspectrogram(y=y, sr=sr)

# Melspec assumes power, not energy as input
melspec_stft = librosa.feature.melspectrogram(S=S**2, sr=sr)

print(np.allclose(melspec, melspec_stft))
# Out:
# True

# %%
plt.figure()
librosa.display.specshow(melspec, y_axis='mel', x_axis='time')
plt.colorbar()
# Out:
# <div id='798d2a4f-1072-40db-8e90-608e316b0899'></div>

# %%
D_harm, D_perc = librosa.decompose.hpss(D)

y_harm = librosa.istft(D_harm)

y_perc = librosa.istft(D_perc)

# %%
Audio(data=y_harm, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
 # %NotebookApp.iopub_data_rate_limit=10000000000000

# %%
W, H = librosa.decompose.decompose(S, n_components=16, sort=True)

# %%
plt.figure(figsize=(6, 3))
plt.subplot(1, 2, 1), plt.title('W')
librosa.display.specshow(librosa.logamplitude(W**2), y_axis='log')
plt.subplot(1, 2, 2), plt.title('H')
librosa.display.specshow(H, x_axis='time')

# %%
S_rec = W[:, :1].dot(H[:1, :])

y_rec = librosa.istft(S_rec * phase)

# %%
Audio(data=y_rec, rate=sr)
